# %% [markdown]
# # **Titanic Survival Prediction**
# **Predict whether a passenger survived or not**

# %% [markdown]
# # **Import Libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **Load Data**

# %%
data = pd.read_csv("/kaggle/input/datasets/ahmedkhafagy000/titanic/train.csv")
df = data.copy()
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # **Quick Data Overview (EDA Basic)**

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
nulls_num = df.isna().sum()
nulls_num
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # **Missing Values Analysis**

# %%
null_percentage = round((nulls_num/len(df))*100,2)
null_percentage
# Out:
# PassengerId     0.00
# Survived        0.00
# Pclass          0.00
# Name            0.00
# Sex             0.00
# Age            19.87
# SibSp           0.00
# Parch           0.00
# Ticket          0.00
# Fare            0.00
# Cabin          77.10
# Embarked        0.22
# dtype: float64

# %%
for col,percent in null_percentage.items():
    print(f"{col}:   {percent}%")
# Out:
# PassengerId:   0.0%
# Survived:   0.0%
# Pclass:   0.0%
# Name:   0.0%
# Sex:   0.0%
# Age:   19.87%
# SibSp:   0.0%
# Parch:   0.0%
# Ticket:   0.0%
# Fare:   0.0%
# Cabin:   77.1%
# Embarked:   0.22%

# %% [markdown]
# # **Exploratory Data Analysis as Plotting (EDA Deep)**

# %% [markdown]
# # **Data Cleaning**

# %%
df = df.drop("PassengerId", axis=1)

# %% [markdown]
# **Replace Age nulls by median because there are outliers in this column**

# %%
df["Age"] = df["Age"].fillna(df["Age"].median())

# %%
print(df["Age"].min())
# Out:
# 0.42

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %% [markdown]
# **Drop Cabin column because it has 77.1% nulls, and we cannot replace or recover these nulls by any way**

# %%
df = df.drop("Cabin",axis=1)
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Embarked
# ...

# %% [markdown]
# # **Feature Engineering**

# %% [markdown]
# # **Encoding**

# %%
numerical_col = df.select_dtypes("number").columns.tolist()
numerical_col
# Out:
# ['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
categorical_col = df.select_dtypes(["object","category"]).columns.tolist()
categorical_col
# Out:
# ['Name', 'Sex', 'Ticket', 'Embarked']

# %%
for itr in categorical_col:
    pass
    #print(f"{itr}: {df[itr].unique()}")
    #print("-" * 30)

# %%
for itr in numerical_col:
    pass
    #print(f"{itr}: {df[itr].unique()}")
    #print("-" * 30)

# %% [markdown]
# **Sex Endcoding(Binary Classification -> Label Encoding)**

# %%
df["Sex"] = df["Sex"].map(
    {
        "male":0,
        "female":1
    }
)

# %% [markdown]
# **Embarked Encoding (Nominal -> One-Hot Encoding)**

# %%
df = pd.get_dummies(df, columns=["Embarked"], dummy_na=True)

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  Sex  \
# 0         0       3                            Braund, Mr. Owen Harris    0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1
# 2         1       3                             Heikkinen, Miss. Laina    1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1
# 4         0       3                           Allen, Mr. William Henry    0
#
#     Age  SibSp  Parch            Ticket     Fare  Embarked_C  Embarked_Q  \
# 0  22.0      1      0         A/5 21171   7.2500       False       False
# 1  38.0      1      0          PC 17599  71.2833        True       False
# 2  26.0      0      0  STON/O2. 3101282   7.9250       False       False
# 3  35.0      1      0            113803  53.1000       False       False
# 4  35.0      0      0            373450   8.0500       False       False
#
#    Embarked_S  Embarked_nan
# 0        True         False
# ...

# %%
df["Embarked_nan"].value_counts()
# Out:
# Embarked_nan
# False    889
# True       2
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age             0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Embarked_C      0
# Embarked_Q      0
# Embarked_S      0
# Embarked_nan    0
# dtype: int64

# %% [markdown]
# # **Train/Test Split**

# %% [markdown]
# # **Model Training**

# %% [markdown]
# # **Evaluation**

# %% [markdown]
# # **Improvement Loop**

# %% [markdown]
# # **Fianl Submission**
